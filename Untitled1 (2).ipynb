# %%
from bing_image_downloader import downloader

# %%
A=["tulip","lotus","rose"]

# %%
n=len(A)
for i in range(n):
    downloader.download(A[i],limit=10,output_dir='dataset')
# Out:
# [%] Downloading Images to C:\Users\hbhar\farh\dataset\tulip
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.gardeningknowhow.com/wp-content/uploads/2008/07/tulips.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.simplemost.com/wp-content/uploads/2020/01/AdobeStock_187888104.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://thedailygardener.org/wp-content/uploads/2019/08/Tulips.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.stgeorgeutah.com/wp-content/uploads/2018/09/tulip-3358577_1920.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.thespruce.com/thmb/OYSoYIo_3PUgc3urTv8KyLgE6yg=/2122x1415/filters:fill(auto,1)/494289973-56a34a3b3df78cf7727cb9d2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.readersdigest.co.uk/media/June 18/tulips.jpg
# [!] Issue getting: https://www.readersdigest.co.uk/media/June 18/tulips.jpg
# [!] Error:: URL can't contain control characters. '/media/June 18/tulips.jpg' (found at least ' ')
# [%] Downloading Image #6 from https://m.media-amazon.com/images/I/91szdSZ03QL.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://www.thespruce.com/thmb/IuuisHGSO72m4wbgoV1r7wd0-zg=/4288x2848/filters:no_upscale():max_bytes(150000):strip_icc()/tulips-planting-and-growing-tulips-1402137-08-aee8737736d848ef95f0a340705d9bf9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://1.bp.blogspot.com/-J9VUnKsCm98/UJGDZjolzjI/AAAAAAAABxc/qJbBCUATI8M/s1600/Tulip_Flower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://hdwpro.com/wp-content/uploads/2016/01/Festival-Tulip.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #10 from http://diplojournal.files.wordpress.com/2010/05/tulips-05.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 10 images.
# [%] Downloading Images to C:\Users\hbhar\farh\dataset\lotus
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/e/ed/Sacred_lotus_Nelumbo_nucifera.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://1.bp.blogspot.com/-lLAeyhqAoqI/VK_nRQmO6bI/AAAAAAAAy70/AZ945yw93kg/s1600/lotus-flower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://s.yimg.com/uu/api/res/1.2/ulewmltQfaNx1.sBb.aOwg--~B/aD0yMDAyO3c9MzE1ODtzbT0xO2FwcGlkPXl0YWNoeW9u/http://media.zenfs.com/en-US/homerun/town_country_721/21ba059af68ff8d5c008dc71b3ff29a5
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://images.pexels.com/photos/720484/pexels-photo-720484.jpeg?auto=compress&amp;cs=tinysrgb&amp;dpr=2&amp;h=650&amp;w=940
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://2.bp.blogspot.com/-CRPnIc-RziA/WTIoWFgTRUI/AAAAAAAAAiI/nE04evuymjUI_jF_SPgDPksT_utMNHBCQCLcB/s1600/lotus-1633174_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://upload.wikimedia.org/wikipedia/commons/8/85/Lotus_Flower_at_GSS.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://wallsdesk.com/wp-content/uploads/2016/09/Lotus-Flower-Images.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://upload.wikimedia.org/wikipedia/commons/0/0e/Fleur-lotus.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://images.squarespace-cdn.com/content/v1/51990477e4b0f50f41c3d666/1548012899082-QAI1OO72I88HBZHRNEVZ/lotus-blossom-newly-open-2-kenilworth-aquatic-gardens_THP.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://www.divinecreativelove.com/wp-content/uploads/beautiful-pink-lotus-flowers.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 10 images.
# [%] Downloading Images to C:\Users\hbhar\farh\dataset\rose
#
#
# [!!]Indexing page: 1
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 0 images.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
image_size = 256
batch_size = 6

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory("dataset",shuffle = True,image_size =(image_size,image_size),batch_size = batch_size)
# Out:
# Found 30 files belonging to 3 classes.

# %%
class_name = dataset.class_names

# %%
class_name
# Out:
# ['lotus', 'rose', 'tulip']

# %%
plt.figure(figsize = (10,10))
for image_batch,label_batch in dataset.take(1):
    for i in range(6):
        plt.subplot(3,2,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_name[label_batch[i]])
        plt.axis('off')
