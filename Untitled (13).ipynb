# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
workface = pd.read_csv('water_potability.csv')

# %%
workface.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
workface.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
workface.dropna(inplace=True)

# %%
workface.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2011.000000  2011.000000   2011.000000  2011.000000  2011.000000
# mean      7.085990   195.968072  21917.441374     7.134338   333.224672
# std       1.573337    32.635085   8642.239815     1.584820    41.205172
# min       0.227499    73.492234    320.942611     1.390871   129.000000
# 25%       6.089723   176.744938  15615.665390     6.138895   307.632511
# 50%       7.027297   197.191839  20933.512750     7.143907   332.232177
# 75%       8.052969   216.441070  27182.587067     8.109726   359.330555
# max      14.000000   317.338124  56488.672413    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   2011.000000     2011.000000      2011.000000  2011.000000  2011.000000
# mean     426.526409       14.357709        66.400859     3.969729     0.403282
# std       80.712572        3.324959        16.077109     0.780346     0.490678
# ...

# %%
sns.boxplot(workface)
# Out:
# <Axes: >

# %%
y=workface['Hardness']
x1=workface['ph']

# %%
plt.scatter(x1,y)
plt.xlabel('ph',fontsize = 20)
plt.ylabel('Hardness',fontsize = 20)
plt.show()

# %%
# x= sm.add_constant(x1)
# results = sm.OLS(y,x).fit()
# results.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x= sm.add_constant(x1)
#       2 results = sm.OLS(y,x).fit()
#       3 results.summary()
#
# NameError: name 'sm' is not defined

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
x1 = workface.iloc[:,0:13] 
y = workface.iloc[:,-1]

# %%
y = np.round(workface['ph'])
bestfeatures = SelectKBest(score_func=chi2, k=5)
fit = bestfeatures.fit(x1,y)
workfacescores = pd.DataFrame(fit.scores_)
workfacecolumns = pd.DataFrame(x1.columns)
featureScores = pd.concat([workfacecolumns,workfacescores],axis=1)
featureScores.columns = ['Solids','Chloramines'] 
featureScores
# Out:
#             Solids    Chloramines
# 0               ph     680.218900
# 1         Hardness     242.780478
# 2           Solids  122468.067272
# 3      Chloramines       9.629568
# 4          Sulfate      93.707670
# 5     Conductivity      95.483739
# 6   Organic_carbon       8.809472
# 7  Trihalomethanes      43.603000
# 8        Turbidity       3.133043
# 9       Potability      22.164894

# %%
print(featureScores.nlargest(5,'Chloramines'))
# Out:
#          Solids    Chloramines
# 2        Solids  122468.067272
# 0            ph     680.218900
# 1      Hardness     242.780478
# 5  Conductivity      95.483739
# 4       Sulfate      93.707670

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(x1,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.5394673  0.06146001 0.05760183 0.05938277 0.05900751 0.05176213
#  0.05354207 0.05444228 0.05555029 0.00778381]

# %%
feat_importances = pd.Series(model.feature_importances_, index=x1.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
x = workface.iloc[:,0:13]
y = workface.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_train)

# %%
print("Training accuracy :" , model.score(x_train,y_train)*100)
# Out:
# Training accuracy : 100.0

# %%
print("Testing accuracy:" ,model.score(x_test,y_test)*100)
# Out:
# Testing accuracy: 100.0

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print("model accuracy:" ,r2_score(y,model.predict(x))*100)
# Out:
# model accuracy: 100.0

# %%
plt.scatter(y_train,y_pred)
plt.xlabel('ph')
plt.ylabel('chloramines')
plt.title('no title')
plt.show()

# %%
print(workface.nunique())
# Out:
# ph                 2011
# Hardness           2011
# Solids             2011
# Chloramines        2011
# Sulfate            2011
# Conductivity       2011
# Organic_carbon     2011
# Trihalomethanes    2011
# Turbidity          2011
# Potability            2
# dtype: int64

# %%
sns.heatmap(workface.isnull())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(workface.corr(), annot= True, cmap='coolwarm')
# Out:
# <Axes: >
