# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
workface=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
workface.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
workface.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
workface.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
        workface.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
workface.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
workface.duplicated().sum()
# Out:
# 0

# %%
sns.barplot(workface)
# Out:
# <Axes: >

# %%
workface['Age'].unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
sns.histplot(workface['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.scatterplot(x='Attrition',y='Age', data=workface)
# Out:
# <Axes: xlabel='Attrition', ylabel='Age'>

# %%
sns.lineplot(x='Age',y='Attrition',data=workface)
# Out:
# <Axes: xlabel='Age', ylabel='Attrition'>

# %%
plt.figure(figsize=(15,8))
sns.heatmap(workface.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.set_style('darkgrid')
sns.countplot(x='Attrition', data=workface)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
workface['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
plt.pie(workface['Attrition'].value_counts().values,labels=workface['Attrition'].value_counts().index,autopct='%1.2f%%',explode=(.15,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x23d1609bd50>,
# ...
#  [Text(-1.0930587195656423, 0.606401381579494, 'No'),
#   Text(0.961891673217765, -0.5336332157899547, 'Yes')],
#  [Text(-0.6558352317393852, 0.3638408289476963, '83.88%'),
#   Text(0.5246681853915082, -0.2910726631581571, '16.12%')])

# %%
workface.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
workface['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
sns.scatterplot(x='Attrition', y='BusinessTravel', data=workface)
# Out:
# <Axes: xlabel='Attrition', ylabel='BusinessTravel'>

# %%
workface.groupby('BusinessTravel')['Attrition'].value_counts()
# Out:
# BusinessTravel     Attrition
# Non-Travel         No           138
#                    Yes           12
# Travel_Frequently  No           208
#                    Yes           69
# Travel_Rarely      No           887
#                    Yes          156
# Name: count, dtype: int64

# %%
workface['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
plt.pie(workface['BusinessTravel'].value_counts().values,labels=workface['BusinessTravel'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x23d1610b310>,
# ...
#  [Text(-0.6728966948858769, 0.8701781645224518, 'Travel_Rarely'),
#   Text(0.36441614894376395, -1.037882878936249, 'Travel_Frequently'),
#   Text(1.0439613016770868, -0.3466191001671471, 'Non-Travel')],
#  [Text(-0.36703456084684194, 0.4746426351940646, '70.95%'),
#   Text(0.19877244487841667, -0.5661179339652267, '18.84%'),
#   Text(0.5694334372784109, -0.18906496372753476, '10.20%')])

# %%
sns.distplot(workface['DailyRate'])
# Out:
# <Axes: xlabel='DailyRate', ylabel='Density'>

# %%
sns.lmplot(x = 'Age', y = 'DailyRate', hue = 'Attrition', data = workface)

# %%
workface['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
workface.groupby('Gender')['Attrition'].value_counts()
# Out:
# Gender  Attrition
# Female  No           501
#         Yes           87
# Male    No           732
#         Yes          150
# Name: count, dtype: int64

# %%
workface.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
workface.groupby('Gender')['DailyRate'].mean()
# Out:
# Gender
# Female    808.273810
# Male      798.626984
# Name: DailyRate, dtype: float64

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='Age',y='Attrition',hue='Gender',style='Gender',markers=True,data=workface)
# Out:
# <Axes: xlabel='Age', ylabel='Attrition'>

# %%
sns.barplot(y='DailyRate',x='Gender',hue='Attrition', data=workface)
# Out:
# <Axes: xlabel='Gender', ylabel='DailyRate'>

# %%
workface.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
workface['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
workface.groupby('Department')['Attrition'].value_counts()
# Out:
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# Name: count, dtype: int64

# %%
sns.countplot(x='Department', hue='Attrition', data=workface)
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
sns.barplot(x='Department',y='DailyRate',hue='Attrition', data=workface)
# Out:
# <Axes: xlabel='Department', ylabel='DailyRate'>

# %%
workface['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
plt.pie(workface['Department'].value_counts().values,labels=workface['Department'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x23d19669650>,
# ...
#  [Text(-0.5108751650946098, 0.9741696801325502, 'Research & Development'),
#   Text(0.37548555701288383, -1.0339296864268501, 'Sales'),
#   Text(1.0900447132085396, -0.1476567750091844, 'Human Resources')],
#  [Text(-0.27865918096069625, 0.5313652800723001, '65.37%'),
#   Text(0.20481030382520934, -0.5639616471419181, '30.34%'),
#   Text(0.5945698435682942, -0.08054005909591874, '4.29%')])

# %%
workface['DistanceFromHome'].unique
# Out:
# <bound method Series.unique of 0        1
# 1        8
# 2        2
# 3        3
# 4        2
#         ..
# 1465    23
# 1466     6
# 1467     4
# 1468     2
# 1469     8
# Name: DistanceFromHome, Length: 1470, dtype: int64>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Age',y='DistanceFromHome',hue='Attrition', data=workface)
# Out:
# <Axes: xlabel='Age', ylabel='DistanceFromHome'>

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='DistanceFromHome',y='Attrition',hue='Gender',markers=True,data=workface)
# Out:
# <Axes: xlabel='DistanceFromHome', ylabel='Attrition'>

# %%
sns.barplot(x='Attrition',y='DistanceFromHome', data=workface)
# Out:
# <Axes: xlabel='Attrition', ylabel='DistanceFromHome'>

# %%
workface.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
workface['Education'].unique
# Out:
# <bound method Series.unique of 0       2
# 1       1
# 2       2
# 3       4
# 4       1
#        ..
# 1465    2
# 1466    1
# 1467    3
# 1468    3
# 1469    3
# Name: Education, Length: 1470, dtype: int64>

# %%
workface.groupby('Education')['Attrition'].value_counts()
# Out:
# Education  Attrition
# 1          No           139
#            Yes           31
# 2          No           238
#            Yes           44
# 3          No           473
#            Yes           99
# 4          No           340
#            Yes           58
# 5          No            43
#            Yes            5
# Name: count, dtype: int64

# %%
sns.countplot(x='Education',hue='Attrition', data=workface)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.catplot(x="Education", y="Attrition", hue="Gender", kind="swarm", data=workface)

# %%
sns.catplot(x="Education", y="Attrition", hue="Gender", kind="bar", data=workface)

# %%
workface.columns

# %%
workface['EducationField'].unique

# %%
workface.groupby('Education')['EducationField'].value_counts()

# %%
sns.countplot(x='EducationField', hue='Attrition', data=workface)

# %%
workface.columns

# %%
workface['EmployeeCount'].unique()

# %%
workface['EmployeeCount'].value_counts()

# %%
sns.countplot(workface['EmployeeCount'])

# %%
workface['EmployeeNumber'].value_counts()

# %%
workface['EnvironmentSatisfaction'].unique()

# %%
sns.countplot(x='EnvironmentSatisfaction', data=workface)

# %%
sns.countplot(x='EnvironmentSatisfaction', hue='Attrition', data=workface)

# %%
workface['HourlyRate'].unique()

# %%
sns.distplot(workface['HourlyRate'])

# %%
sns.barplot(x='HourlyRate', y='Attrition', data=workface)

# %%
workface.columns

# %%
workface['JobInvolvement'].unique()

# %%
workface.groupby('JobInvolvement')['JobInvolvement'].value_counts()

# %%
sns.countplot(x='JobInvolvement',hue='Attrition',data=workface)

# %%
workface['JobLevel'].unique()

# %%
sns.countplot(workface['JobLevel'])

# %%
sns.countplot(x='JobLevel', hue='Attrition', data=workface)

# %%
workface['JobRole'].unique()

# %%
workface['JobRole'].value_counts()

# %%
sns.barplot(x='MonthlyIncome',y='JobRole',data=workface)

# %%
workface.columns

# %%
workface['JobSatisfaction'].unique()

# %%
sns.countplot(workface['JobSatisfaction'])

# %%
sns.countplot(x='JobSatisfaction', hue='Attrition', data=workface)

# %%
workface['MaritalStatus'].value_counts()

# %%
sns.countplot(x='MaritalStatus', hue='Attrition',data=workface)

# %%
workface['MonthlyIncome'].unique()

# %%
sns.distplot(workface['MonthlyIncome'])

# %%
sns.scatterplot(x='Age', y='MonthlyIncome',hue='Attrition', data=workface)

# %%
sns.distplot(workface['MonthlyRate'])

# %%
workface['NumCompaniesWorked'].unique()

# %%
sns.scatterplot(x='NumCompaniesWorked',y='MonthlyIncome',hue='Attrition', data=workface)

# %%
sns.distplot(workface['NumCompaniesWorked'])

# %%
workface['Over18'].unique()

# %%
workface['OverTime'].unique()

# %%
workface['PercentSalaryHike'].unique()

# %%
sns.swarmplot(data = workface, x='Attrition', y='PercentSalaryHike')

# %%
sns.violinplot(data = workface, x='Attrition', y='PercentSalaryHike')

# %%
workface['PerformanceRating'].unique()

# %%
workface['PerformanceRating'].value_counts()

# %%
sns.countplot(x='PerformanceRating',hue='Attrition', data=workface)

# %%
workface['RelationshipSatisfaction'].unique()

# %%
workface.groupby('RelationshipSatisfaction')['Attrition'].value_counts()

# %%
workface.columns

# %%
workface['StandardHours'].unique()

# %%
workface['StandardHours'].nunique()

# %%
workface['StockOptionLevel'].unique()

# %%
workface['TotalWorkingYears'].unique()

# %%
sns.scatterplot(x='MonthlyIncome',y='TotalWorkingYears', hue='Attrition', data=workface)

# %%
sns.distplot(workface['TotalWorkingYears'])

# %%
workface['TrainingTimesLastYear'].unique()

# %%
workface['WorkLifeBalance'].unique()

# %%
workface.groupby('WorkLifeBalance')['Attrition'].value_counts()

# %%
workface['YearsAtCompany'].unique()

# %%
sns.scatterplot(x='Age',y='YearsAtCompany',hue='Attrition',data=workface)

# %%
workface.columns

# %%
workface['Attrition'].nunique()

# %%
workface['Attrition'].unique()

# %%
workface['Attrition'].value_counts()

# %%
workface['Attrition']=np.where(workface['Attrition']=='Yes',1,0)

# %%
workface.head()

# %%
workface.shape

# %%
a=workface.drop('Attrition', axis=1)
b=workface['Attrition']

# %%
a.shape , b.shape

# %%
workface=pd.concat([a,b], axis=1)

# %%
workface.shape

# %%
sns.pairplot(workface)

# %%
# plt.figure(figsize=(20, 20))
# sns.heatmap(workface.corr(), annot=True, linecolor='red', linewidths=0.25)

# %%
num=workface.select_dtypes(np.number)

# %%
num.drop('Attrition',axis=1, inplace=True)

# %%
num.columns

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
standard=sc.fit_transform(num)

# %%
standard=pd.DataFrame(standard, columns=num.columns)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF= pd.DataFrame()
VIF['features']= standard.columns
VIF['vif']=[variance_inflation_factor(standard.values,i) for i in range(len(standard.columns))]

# %%
VIF

# %%
num.shape

# %%
standard.drop(['EmployeeCount','EmployeeNumber','StandardHours','JobLevel'], axis=1, inplace=True)

# %%
standard.shape

# %%
VIF= pd.DataFrame()
VIF['features']= standard.columns
VIF['vif']=[variance_inflation_factor(standard.values,i) for i in range(len(standard.columns))]

# %%
VIF

# %%
workface.drop(['EmployeeCount','EmployeeNumber','StandardHours','JobLevel','Over18'], axis=1, inplace=True)

# %%
workface.shape

# %%
plt.figure(figsize=(20,20),dpi=200)
sns.heatmap(workface.corr(),annot=True, linecolor='white',linewidths=.25)

# %%
workface.skew()

# %%
num= workface.select_dtypes(np.number)

# %%
workface.plot(kind='box', subplots=True, layout=(5,5),figsize=(15,10))

# %%
for i in num:
    sns.boxplot(workface[i])
    plt.show()

# %%
workface['MonthlyIncome'].unique()

# %%
workface['MonthlyIncome'].describe()

# %%
workface['NumCompaniesWorked'].describe()

# %%
workface[workface['NumCompaniesWorked']==9]

# %%
workface['PercentSalaryHike'].unique()

# %%
workface['PercentSalaryHike'].describe()

# %%
workface['PerformanceRating'].unique()

# %%
workface['StockOptionLevel'].unique()

# %%
workface['TotalWorkingYears'].unique()

# %%
workface['TotalWorkingYears'].describe()

# %%
workface['TotalWorkingYears'].max()

# %%
workface[workface['TotalWorkingYears']==40]

# %%
workface['TrainingTimesLastYear'].unique()

# %%
workface['TrainingTimesLastYear'].describe()

# %%
workface['YearsAtCompany'].unique()

# %%
workface['YearsAtCompany'].max()

# %%
workface[workface['YearsAtCompany']==40]

# %%
workface['YearsInCurrentRole'].unique()

# %%
workface['YearsInCurrentRole'].describe()

# %%
sns.distplot(workface['YearsInCurrentRole'])

# %%
workface['YearsSinceLastPromotion'].unique()

# %%
sns.distplot(workface['YearsSinceLastPromotion'])

# %%
workface['YearsWithCurrManager'].unique()

# %%
workface[workface['YearsWithCurrManager']==16]

# %%
workface.columns

# %%
workface.select_dtypes('O')

# %%
workface.shape

# %%
workface['Attrition'].value_counts()

# %%
workface.head

# %%
X= workface.drop('Attrition', axis=1)
Y=workface['Attrition']

# %%
X.shape , Y.shape

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
X.shape

# %%
X.skew()

# %%
Y.head(10)

# %%
Y.value_counts()

# %%
from sklearn.preprocessing import power_transform
transformed=power_transform(X)

# %%
pd.DataFrame(transformed).skew()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
scaled=sc.fit_transform(transformed)

# %%
X= scaled

# %%
pip install imbalanced-learn

# %%
pip install --upgrade scikit-learn

# %%
# !pip install imblearn

# %%
# !pip install imbalanced-learn scikit-learn
# !pip cache purge

# %%
from imbalanced_learn import UnderSampler, OverSampler, SMOTE

# %%
sm = SMOTE()

# %%
x,y=sm.fit_resample(X,Y)

# %%
x.shape , y.shape

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
maxaccu=0
maxRS=0

for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=i,test_size=.20)
    LR= LogisticRegression()
    LR.fit(x_train,y_train)
    pred= LR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxRS=i
print("Best accuracy is ",maxaccu,"on Random State =",maxRS)

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=197,test_size=.20)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
# !pip install xgboost

# %%
LR_model= LogisticRegression()
RD_model= RidgeClassifier()
DT_model= DecisionTreeClassifier()
SV_model= SVC()
KNR_model= KNeighborsClassifier()
RFR_model= RandomForestClassifier()
XGB_model= XGBClassifier()
SGH_model= SGDClassifier()
Bag_model=BaggingClassifier()
ADA_model=AdaBoostClassifier()
GB_model= GradientBoostingClassifier()

model=[LR_model,RD_model,DT_model,SV_model,KNR_model,RFR_model,XGB_model,SGH_model,Bag_model,ADA_model,GB_model ]

# %%
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred= m.predict(x_test)
    print('Accuracy_Score of ',m, 'is', accuracy_score(y_test,pred)*100)
    print('Confusion Matrix of ',m,' is \n', confusion_matrix(y_test,pred) )
    print(classification_report(y_test,pred))
    print('*'*50)

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in model:
    print('Accuracy_Score of ',i, 'is', accuracy_score(y_test,i.predict(x_test))*100)
    print("cross Validation accuracy score of ",i ," is ",cross_val_score(i,x,y,cv=5, scoring='accuracy').mean()*100)
    print('*'*50)

# %%
n_estimator= [200, 400, 600, 800, 1000]  # no of tree in Random forest, default is 100
max_features= ['auto','sqrt','log2']  # mini no of features to create Decission Tree
max_depth=[10, 64, 118, 173, 227, 282, 336]  #  Max depth of decision tree
min_samples_split= [1,2,3]   # mini no of sample rerquired to split node
min_samples_leaf= [1,3,4,6,7,9]  #mini no of sample required at each leaf node

param_grid= {'n_estimators': n_estimator,
             'max_features':max_features,
             'max_depth':max_depth,
             'min_samples_split':min_samples_split,
             'min_samples_leaf':min_samples_leaf,
             }
param_grid

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search=GridSearchCV(estimator=RFR_model,param_grid=param_grid,cv=5,n_jobs=-1,verbose=2)
grid_search.fit(x_train,y_train)

# %%
grid_search.best_estimator_

# %%
grid_search.best_params_

# %%
GCV_pred=grid_search.best_estimator_.predict(x_test)
accuracy_score(y_test,GCV_pred)

# %%
from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve

# %%
plot_roc_curve(grid_search.best_estimator_,x_test,y_test)
plt.title('ROC AUC Plot')
plt.show()
